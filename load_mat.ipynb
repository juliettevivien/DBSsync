# %%
import mne
from mne.io import read_raw_fieldtrip
import os

# %%
sess = "sub-007_ses-Fu03mMedOff_task-Rest_acq-StimOn2R110Hz60us_run-1"
filepath = "C:\\Users\\Juliette\\OneDrive - Charité - Universitätsmedizin Berlin\\Fichiers de Kaplan, Jonathan - EntrainERNA\\derivatives\\synced\\sub-007\\ses-Fu03mMedOff"
file_name_lfp = os.path.join(filepath, f"SYNCHRONIZED_INTRACRANIAL_{sess}_lfp.mat")
file_name_acc = os.path.join(filepath, f"SYNCHRONIZED_EXTERNAL_{sess}_acc.mat")

# %%
import scipy.io as sio

mat_acc = sio.loadmat(file_name_acc, struct_as_record=False, squeeze_me=True)
mat_lfp = sio.loadmat(file_name_lfp, struct_as_record=False, squeeze_me=True)
# print(type(mat["data"]))
# print(mat["data"])

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
len(mat_acc)
# Out:
# 6

# %%
sf_acc = 4000
sf_lfp = 250

# %%
times_acc = np.arange(mat_acc['data'].shape[1]) / sf_acc
times_lfp = np.arange(mat_lfp['data'].shape[1]) / sf_lfp

# %%
# %matplotlib qt
fig, axes = plt.subplots(2, 1)
axes[0].plot(times_acc, mat_acc['data'][6], color = 'black', linewidth=0.3)
axes[1].plot(times_lfp, mat_lfp['data'][0]*100, linewidth=0.3, color='black')  # scale LFP for better visualization

# %%
# plt.plot(times_acc, mat_acc['data'][9], color = 'black', linewidth=0.3)
plt.plot(times_lfp, mat_lfp['data'][0]*100, linewidth=0.3, color='grey')

# %%
mat_acc
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file Platform: nt, Created on: Tue Jan 27 09:07:31 2026',
#  '__version__': '1.0',
#  '__globals__': [],
#  'data': array([[-1.61006585e-01, -1.60532460e-01, -1.61246628e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 9.85828698e-01,  9.80303407e-01,  9.81677234e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [-1.56764060e-01, -1.63974524e-01, -1.62998304e-01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         ...,
#         [-3.89999962e+01, -3.89999962e+01, -5.45999985e+01, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 2.06969648e+04,  2.05362930e+04,  2.05417617e+04, ...,
#           0.00000000e+00,  0.00000000e+00,  0.00000000e+00],
#         [ 0.00000000e+00,  2.50000385e-04,  5.00000770e-04, ...,
#           1.62400250e+02,  1.62400500e+02,  1.62400750e+02]]),
#  'fsample': 4000.0,
# ...

# %%
plt.plot(mat_acc['data'][9])
